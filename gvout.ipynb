# %%
# %reload_ext gvmagic

# %%
# !dot -V
# Out:
# dot - graphviz version 2.38.0 (20140413.2041)

# %%
# %%dot
#
# digraph{
#     centre=True;
#     layout="dot";
#     rankdir="LR";
#     node [shape=box];
#     splines="ortho";
#     label="Figure Caption";
#     edge [arrowhead="empty"];
#     subgraph cluster_0{
#         label="Line of Boxes";
#
#         a->b->c->d:es->e->f->g->h;
#         h->j[arrowhead="normal"];
#         {rank=same;a, e}
#     }
# }
